# %%
import pandas as pd
df1 = pd.DataFrame(np.random.randn(5,4),columns = list(['red','green','yellow','blue']))
print(df1)
# Out:
#         red     green    yellow      blue
# 0 -0.934204  0.447249  0.364924  0.315975
# 1 -0.036167  0.712343 -0.922306  0.542638
# 2  0.335695  0.496524 -1.185542  0.227448
# 3 -0.662918 -0.326744  0.576604  1.042739
# 4 -0.784504 -0.432150  2.258160 -0.477041

# %%
df1.plot()

# %%
df1.plot.bar()

# %%
df1.plot.bar(stacked =true)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-bec94eab8fe8> in <module>
# ----> 1 df1.plot.bar(stacked =true)
#
# NameError: name 'true' is not defined

# %%
df1.plot.hist(bins=10)

# %%
df1.plot.box()

# %%
import matplotlib.pyplot as plt
fig = plt.figure()
ax = plt.axes()

# %%
plt.plot([2,4,5],[6,7,8])
plt.show()

# %%
import numpy as np
x = np.linspace(0,10,1000)
plt.plot(x,np.cos(x))
plt.show()

# %%
import numpy as np
x = np.linspace(0,10,1000)
plt.plot(x,np.cos(x),linestyle='solid',color='black')
plt.plot(x,np.cos(x-1),linestyle = 'dashed',color='r')
plt.plot(x,np.cos(x-2),linestyle = 'dotted',color ='0.50')
plt.show()
